# %%
# %load_ext autoreload
# %autoreload 2

# %%
from IPython.core.display import display, HTML
from h3 import h3

import json
import pandas as pd
from pandas.io.json import json_normalize
import numpy as np

# %%
from geojson.feature import *
from area import area

import copy

# %%
from folium import Map, Marker, GeoJson
from folium.plugins import MarkerCluster
import branca.colormap as cm
from branca.colormap import linear
import folium

import seaborn as sns
import matplotlib.pyplot as plt

# %%
from IPython.display import Image, display
from IPython.utils.text import columnize
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

# %%
from locdata.dataset.geojson import GeoJsonDataset

# %%
gds = GeoJsonDataset("../data/osm_nodes_amnenities_dc_bbox.geojson")
# Out:
# ../data/osm_nodes_amnenities_dc_bbox.geojson
# Cleaning null geometries, eliminated  0  rows out of the original  5627  rows
# ['id', 'Latitude', 'Longitude', 'properties.name', 'properties.amenity', 'properties.cusine', 'properties.addr:housenumber', 'properties.addr:street', 'properties.addr:city', 'properties.addr:state', 'properties.addr:postcode']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-841f8a7192e5> in <module>
# ----> 1 gds = GeoJsonDataset("../data/osm_nodes_amnenities_dc_bbox.geojson")
#
# ~/projects/locdata/locdata/src/locdata/dataset/geojson.py in __init__(self, source, properties)
#      16         else:
#      17             self.properties = properties
# ---> 18         self.df = self._read_geojson()
#      19
#      20
#
# ~/projects/locdata/locdata/src/locdata/dataset/geojson.py in _read_geojson(self)
#      43             [f"properties.{p}" for p in self.properties])
#      44         print(selection)
# ---> 45         df = df[selection]
#      46         return df
#
# ~/projects/locdata/locdata/venv/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~/projects/locdata/locdata/venv/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ~/projects/locdata/locdata/venv/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1643             if not (self.name == "loc" and not raise_missing):
#    1644                 not_found = list(set(key) - set(ax))
# -> 1645                 raise KeyError(f"{not_found} not in index")
#    1646
#    1647             # we skip the warning on Categorical/Interval
#
# KeyError: "['properties.cusine', 'Latitude', 'Longitude'] not in index"

# %%
gds.df.head(50)
# Out:
#        type              id  properties.@id properties.addr:housenumber  \
# 0   Feature   node/60471261   node/60471261                        1847
# 1   Feature  node/291675307  node/291675307                         NaN
# 2   Feature  node/306011118  node/306011118                         NaN
# 3   Feature  node/306011599  node/306011599                         NaN
# 4   Feature  node/306020851  node/306020851                         NaN
# 5   Feature  node/306496893  node/306496893                         NaN
# 6   Feature  node/306499334  node/306499334                         NaN
# 7   Feature  node/306507109  node/306507109                         NaN
# 8   Feature  node/306514470  node/306514470                         NaN
# 9   Feature  node/306516802  node/306516802                         NaN
# 10  Feature  node/309514349  node/309514349                         NaN
# 11  Feature  node/309522679  node/309522679                         NaN
# 12  Feature  node/310423111  node/310423111                         NaN
# 13  Feature  node/310423217  node/310423217                         NaN
# 14  Feature  node/310423237  node/310423237                         NaN
# 15  Feature  node/310423257  node/310423257                         NaN
# 16  Feature  node/310843963  node/310843963                         NaN
# 17  Feature  node/340148262  node/340148262                         NaN
# 18  Feature  node/356559879  node/356559879                         NaN
# 19  Feature  node/356561279  node/356561279                         NaN
# 20  Feature  node/356567851  node/356567851                         NaN
# 21  Feature  node/356580549  node/356580549                         NaN
# 22  Feature  node/356580569  node/356580569                         NaN
# 23  Feature  node/356580935  node/356580935                         NaN
# 24  Feature  node/356580943  node/356580943                         NaN
# 25  Feature  node/356580945  node/356580945                         NaN
# 26  Feature  node/356580961  node/356580961                         NaN
# 27  Feature  node/356580966  node/356580966                         NaN
# 28  Feature  node/356580970  node/356580970                         NaN
# 29  Feature  node/356586213  node/356586213                         NaN
# 30  Feature  node/356586223  node/356586223                         NaN
# 31  Feature  node/356588861  node/356588861                         NaN
# 32  Feature  node/356600926  node/356600926                         NaN
# 33  Feature  node/356600955  node/356600955                         NaN
# 34  Feature  node/356605852  node/356605852                         NaN
# 35  Feature  node/356605946  node/356605946                        1701
# 36  Feature  node/356605951  node/356605951                         NaN
# 37  Feature  node/356606003  node/356606003                         NaN
# 38  Feature  node/356606026  node/356606026                         NaN
# 39  Feature  node/356606044  node/356606044                         NaN
# 40  Feature  node/356606150  node/356606150                         NaN
# 41  Feature  node/356606630  node/356606630                        1701
# 42  Feature  node/356606812  node/356606812                        2847
# 43  Feature  node/358245227  node/358245227                         NaN
# 44  Feature  node/358245283  node/358245283                         NaN
# 45  Feature  node/358245728  node/358245728                         NaN
# 46  Feature  node/358253511  node/358253511                         NaN
# 47  Feature  node/358253555  node/358253555                         NaN
# 48  Feature  node/358255948  node/358255948                         NaN
# 49  Feature  node/358256150  node/358256150                         NaN
#
#    properties.addr:postcode properties.addr:street properties.amenity  \
# 0                     20009  14th Street Northwest                bar
# 1                       NaN                    NaN         university
# 2                       NaN                    NaN       fire_station
# 3                       NaN                    NaN       fire_station
# 4                       NaN                    NaN       fire_station
# 5                       NaN                    NaN       fire_station
# 6                       NaN                    NaN       fire_station
# 7                       NaN                    NaN       fire_station
# 8                       NaN                    NaN       fire_station
# 9                       NaN                    NaN       fire_station
# 10                      NaN                    NaN    bicycle_parking
# 11                      NaN                    NaN               fuel
# 12                      NaN                    NaN   parking_entrance
# 13                      NaN                    NaN   parking_entrance
# 14                      NaN                    NaN   parking_entrance
# 15                      NaN                    NaN   parking_entrance
# 16                      NaN                    NaN    bicycle_parking
# 17                      NaN                    NaN               cafe
# 18                      NaN                    NaN         grave_yard
# 19                      NaN                    NaN             school
# 20                      NaN                    NaN             school
# 21                      NaN                    NaN   place_of_worship
# 22                      NaN                    NaN   place_of_worship
# 23                      NaN                    NaN   place_of_worship
# 24                      NaN                    NaN   place_of_worship
# 25                      NaN                    NaN   place_of_worship
# 26                      NaN                    NaN   place_of_worship
# 27                      NaN                    NaN   place_of_worship
# 28                      NaN                    NaN   place_of_worship
# 29                      NaN                    NaN        post_office
# 30                      NaN                    NaN        post_office
# 31                      NaN                    NaN        post_office
# 32                      NaN                    NaN         grave_yard
# 33                      NaN                    NaN         grave_yard
# 34                      NaN                    NaN   place_of_worship
# 35                    22302      North Quaker Lane   place_of_worship
# 36                      NaN                    NaN   place_of_worship
# 37                      NaN                    NaN             school
# 38                      NaN                    NaN        post_office
# 39                      NaN                    NaN             school
# 40                      NaN                    NaN             school
# 41                    22302      North Quaker Lane             school
# 42                    22201            Wilson Blvd             school
# 43                      NaN                    NaN             school
# 44                      NaN                    NaN             school
# 45                      NaN                    NaN             school
# 46                      NaN                    NaN   place_of_worship
# 47                      NaN                    NaN             school
# 48                      NaN                    NaN   place_of_worship
# 49                      NaN                    NaN   place_of_worship
#
#    properties.atm properties.cuisine  \
# 0             yes     Classic Bistro
# 1             NaN                NaN
# 2             NaN                NaN
# 3             NaN                NaN
# 4             NaN                NaN
# 5             NaN                NaN
# 6             NaN                NaN
# 7             NaN                NaN
# 8             NaN                NaN
# 9             NaN                NaN
# 10            NaN                NaN
# 11            NaN                NaN
# 12            NaN                NaN
# 13            NaN                NaN
# 14            NaN                NaN
# 15            NaN                NaN
# 16            NaN                NaN
# 17            NaN        coffee_shop
# 18            NaN                NaN
# 19            NaN                NaN
# 20            NaN                NaN
# 21            NaN                NaN
# 22            NaN                NaN
# 23            NaN                NaN
# 24            NaN                NaN
# 25            NaN                NaN
# 26            NaN                NaN
# 27            NaN                NaN
# 28            NaN                NaN
# 29            NaN                NaN
# 30            NaN                NaN
# 31            NaN                NaN
# 32            NaN                NaN
# 33            NaN                NaN
# 34            NaN                NaN
# 35            NaN                NaN
# 36            NaN                NaN
# 37            NaN                NaN
# 38            NaN                NaN
# 39            NaN                NaN
# 40            NaN                NaN
# 41            NaN                NaN
# 42            NaN                NaN
# 43            NaN                NaN
# 44            NaN                NaN
# 45            NaN                NaN
# 46            NaN                NaN
# 47            NaN                NaN
# 48            NaN                NaN
# 49            NaN                NaN
#
#                                       properties.name  ...  \
# 0                                       Cafe Saint Ex  ...
# 1                    The George Washington University  ...
# 2   District of Columbia Fire and Emergency Medica...  ...
# 3             DC Fire Department Engine Company No. 1  ...
# 4                     DC Fire Department Engine Co. 3  ...
# 5                    DC Fire Department Engine Co. 10  ...
# 6        DC Fire Department Engine Co. 11/Truck Co. 6  ...
# 7                    DC Fire Department Engine Co. 15  ...
# 8                    DC Fire Department Engine Co. 21  ...
# 9                     D Fire Department Engine Co. 25  ...
# 10                                                NaN  ...
# 11                                             Sunoco  ...
# 12                                                NaN  ...
# 13                                                NaN  ...
# 14                                                NaN  ...
# 15                                                NaN  ...
# 16                                                NaN  ...
# 17                                          Starbucks  ...
# 18                        Arlington National Cemetery  ...
# 19                       Drew Model Elementary School  ...
# 20                  Charles Barrett Elementary School  ...
# 21                   Abundant Life United Holy Church  ...
# 22                         Community Methodist Church  ...
# 23             Beverley Hills United Methodist Church  ...
# 24          Christian Science 2nd Church of Arlington  ...
# 25                           Calvary Methodist Church  ...
# 26                     Our Lady Queen of Peace Church  ...
# 27                         Mount Olive Baptist Church  ...
# 28           Lomax African Methodist Episcopal Church  ...
# 29                        Arlington South Post Office  ...
# 30                             Courthouse Post Office  ...
# 31                      George Washington Post Office  ...
# 32                                     Lomax Cemetery  ...
# 33                            Syphax Family Graveyard  ...
# 34       Missionary Servants of the Most Holy Trinity  ...
# 35                     Saint Clement Episcopal Church  ...
# 36                                  Saint Rita Church  ...
# 37                             Grace Episcopal School  ...
# 38                 Bolling Air Force Base Post Office  ...
# 39        Arlington United Methodist Church Preschool  ...
# 40                                     Embassy School  ...
# 41                     Saint Clement Episcopal School  ...
# 42  Arlington County New Directions Alternative Ce...  ...
# 43                     Green Valley Elementary School  ...
# 44                                 Holy Family School  ...
# 45                    G Gardner Shugart Middle School  ...
# 46                           Hillcrest Baptist Church  ...
# 47                  Panorama Special Education Center  ...
# 48               Cornerstone Baptist Community Church  ...
# 49                   Spirit of Faith Christian Center  ...
#
#    properties.operator:type properties.after_school properties.isced:level  \
# 0                       NaN                     NaN                    NaN
# 1                       NaN                     NaN                    NaN
# 2                       NaN                     NaN                    NaN
# 3                       NaN                     NaN                    NaN
# 4                       NaN                     NaN                    NaN
# 5                       NaN                     NaN                    NaN
# 6                       NaN                     NaN                    NaN
# 7                       NaN                     NaN                    NaN
# 8                       NaN                     NaN                    NaN
# 9                       NaN                     NaN                    NaN
# 10                      NaN                     NaN                    NaN
# 11                      NaN                     NaN                    NaN
# 12                      NaN                     NaN                    NaN
# 13                      NaN                     NaN                    NaN
# 14                      NaN                     NaN                    NaN
# 15                      NaN                     NaN                    NaN
# 16                      NaN                     NaN                    NaN
# 17                      NaN                     NaN                    NaN
# 18                      NaN                     NaN                    NaN
# 19                      NaN                     NaN                    NaN
# 20                      NaN                     NaN                    NaN
# 21                      NaN                     NaN                    NaN
# 22                      NaN                     NaN                    NaN
# 23                      NaN                     NaN                    NaN
# 24                      NaN                     NaN                    NaN
# 25                      NaN                     NaN                    NaN
# 26                      NaN                     NaN                    NaN
# 27                      NaN                     NaN                    NaN
# 28                      NaN                     NaN                    NaN
# 29                      NaN                     NaN                    NaN
# 30                      NaN                     NaN                    NaN
# 31                      NaN                     NaN                    NaN
# 32                      NaN                     NaN                    NaN
# 33                      NaN                     NaN                    NaN
# 34                      NaN                     NaN                    NaN
# 35                      NaN                     NaN                    NaN
# 36                      NaN                     NaN                    NaN
# 37                      NaN                     NaN                    NaN
# 38                      NaN                     NaN                    NaN
# 39                      NaN                     NaN                    NaN
# 40                      NaN                     NaN                    NaN
# 41                      NaN                     NaN                    NaN
# 42                      NaN                     NaN                    NaN
# 43                      NaN                     NaN                    NaN
# 44                      NaN                     NaN                    NaN
# 45                      NaN                     NaN                    NaN
# 46                      NaN                     NaN                    NaN
# 47                      NaN                     NaN                    NaN
# 48                      NaN                     NaN                    NaN
# 49                      NaN                     NaN                    NaN
#
#    properties.nursery properties.preschool properties.toilets:disposal  \
# 0                 NaN                  NaN                         NaN
# 1                 NaN                  NaN                         NaN
# 2                 NaN                  NaN                         NaN
# 3                 NaN                  NaN                         NaN
# 4                 NaN                  NaN                         NaN
# 5                 NaN                  NaN                         NaN
# 6                 NaN                  NaN                         NaN
# 7                 NaN                  NaN                         NaN
# 8                 NaN                  NaN                         NaN
# 9                 NaN                  NaN                         NaN
# 10                NaN                  NaN                         NaN
# 11                NaN                  NaN                         NaN
# 12                NaN                  NaN                         NaN
# 13                NaN                  NaN                         NaN
# 14                NaN                  NaN                         NaN
# 15                NaN                  NaN                         NaN
# 16                NaN                  NaN                         NaN
# 17                NaN                  NaN                         NaN
# 18                NaN                  NaN                         NaN
# 19                NaN                  NaN                         NaN
# 20                NaN                  NaN                         NaN
# 21                NaN                  NaN                         NaN
# 22                NaN                  NaN                         NaN
# 23                NaN                  NaN                         NaN
# 24                NaN                  NaN                         NaN
# 25                NaN                  NaN                         NaN
# 26                NaN                  NaN                         NaN
# 27                NaN                  NaN                         NaN
# 28                NaN                  NaN                         NaN
# 29                NaN                  NaN                         NaN
# 30                NaN                  NaN                         NaN
# 31                NaN                  NaN                         NaN
# 32                NaN                  NaN                         NaN
# 33                NaN                  NaN                         NaN
# 34                NaN                  NaN                         NaN
# 35                NaN                  NaN                         NaN
# 36                NaN                  NaN                         NaN
# 37                NaN                  NaN                         NaN
# 38                NaN                  NaN                         NaN
# 39                NaN                  NaN                         NaN
# 40                NaN                  NaN                         NaN
# 41                NaN                  NaN                         NaN
# 42                NaN                  NaN                         NaN
# 43                NaN                  NaN                         NaN
# 44                NaN                  NaN                         NaN
# 45                NaN                  NaN                         NaN
# 46                NaN                  NaN                         NaN
# 47                NaN                  NaN                         NaN
# 48                NaN                  NaN                         NaN
# 49                NaN                  NaN                         NaN
#
#    properties.toilets:position properties.display  longitude   latitude
# 0                          NaN                NaN -77.031701  38.915421
# 1                          NaN                NaN -77.046322  38.899231
# 2                          NaN                NaN -77.016108  38.907691
# 3                          NaN                NaN -77.049753  38.905433
# 4                          NaN                NaN -77.010947  38.895818
# 5                          NaN                NaN -76.986740  38.901548
# 6                          NaN                NaN -77.033029  38.932277
# 7                          NaN                NaN -76.986076  38.864849
# 8                          NaN                NaN -77.042228  38.924712
# 9                          NaN                NaN -77.000744  38.843218
# 10                         NaN                NaN -77.072110  38.906809
# 11                         NaN                NaN -77.072711  38.896305
# 12                         NaN                NaN -77.063962  38.882854
# 13                         NaN                NaN -77.064078  38.882815
# 14                         NaN                NaN -77.062924  38.881103
# 15                         NaN                NaN -77.063999  38.882667
# 16                         NaN                NaN -77.082935  38.899628
# 17                         NaN                NaN -77.029389  38.916843
# 18                         NaN                NaN -77.073785  38.879374
# 19                         NaN                NaN -77.086798  38.847913
# 20                         NaN                NaN -77.077123  38.842025
# 21                         NaN                NaN -77.079700  38.899001
# 22                         NaN                NaN -77.089713  38.892937
# 23                         NaN                NaN -77.068311  38.839002
# 24                         NaN                NaN -77.092478  38.873168
# 25                         NaN                NaN -77.058033  38.853446
# 26                         NaN                NaN -77.083153  38.854145
# 27                         NaN                NaN -77.073589  38.862057
# 28                         NaN                NaN -77.082284  38.847786
# 29                         NaN                NaN -77.092226  38.859064
# 30                         NaN                NaN -77.083784  38.891954
# 31                         NaN                NaN -77.061922  38.839002
# 32                         NaN                NaN -77.082005  38.847454
# 33                         NaN                NaN -77.075259  38.870186
# 34                         NaN                NaN -77.079234  38.887495
# 35                         NaN                NaN -77.084961  38.833343
# 36                         NaN                NaN -77.063586  38.838590
# 37                         NaN                NaN -77.064492  38.837252
# 38                         NaN                NaN -77.011100  38.844300
# 39                         NaN                NaN -77.093249  38.864799
# 40                         NaN                NaN -77.089851  38.892775
# 41                         NaN                NaN -77.084952  38.832412
# 42                         NaN                NaN -77.092854  38.889034
# 43                         NaN                NaN -76.964470  38.840751
# 44                         NaN                NaN -76.964195  38.836474
# 45                         NaN                NaN -76.968288  38.834174
# 46                         NaN                NaN -76.961081  38.833172
# 47                         NaN                NaN -76.969419  38.835669
# 48                         NaN                NaN -76.964292  38.839084
# 49                         NaN                NaN -76.967688  38.842113
#
# [50 rows x 300 columns]

# %%
for c in gds.df.columns:
    print(c)
# Out:
# type
# id
# properties.@id
# properties.addr:housenumber
# properties.addr:postcode
# properties.addr:street
# properties.amenity
# properties.atm
# properties.cuisine
# properties.name
# properties.opening_hours
# properties.phone
# properties.website
# properties.wheelchair
# geometry.type
# geometry.coordinates
# properties.created_by
# properties.addr:state
# properties.ele
# properties.gnis:county_name
# properties.gnis:feature_id
# properties.gnis:import_uuid
# properties.gnis:reviewed
# properties.source
# properties.brand
# properties.brand:wikidata
# properties.brand:wikipedia
# properties.official_name
# properties.takeaway
# properties.addr:country
# properties.gnis:county_id
# properties.gnis:created
# properties.gnis:state_id
# properties.gnis:edited
# properties.operator
# properties.religion
# properties.denomination
# properties.addr:city
# properties.building
# properties.wikidata
# properties.wikipedia
# properties.social_facility
# properties.social_facility:for
# properties.historic
# properties.fixme
# properties.disused
# properties.old_name
# properties.healthcare
# properties.network
# properties.healthcare:speciality
# properties.beds
# properties.description
# properties.toilets:wheelchair
# properties.layer
# properties.level
# properties.short_name
# properties.dataset
# properties.dcgis:lot
# properties.dcgis:square
# properties.FIXME
# properties.country
# properties.diplomatic
# properties.name:de
# properties.alt_name
# properties.alt_name_1
# properties.gnis:feature_id_1
# properties.gnis:import_uuid_1
# properties.historic_1
# properties.name:es
# properties.note
# properties.old_ref
# properties.source_1
# properties.url
# properties.designation
# properties.internet_access
# properties.room
# properties.tiger:reviewed
# properties.covered
# properties.fee
# properties.parking
# properties.outdoor_seating
# properties.food
# properties.drive_through
# properties.opening_hours:rubbish
# properties.contact:website
# properties.diet:vegan
# properties.diet:vegetarian
# properties.vending
# properties.wpt_description
# properties.type
# properties.wpt_symbol
# properties.dc-gis:dataset
# properties.dc-gis:pubdate
# properties.location
# properties.recycling_type
# properties.name:en
# properties.delivery
# properties.backrest
# properties.marker_text
# properties.diet:halal
# properties.smoking
# properties.dcgis:dataset
# properties.dcgis:gis_id
# properties.dcgis:pubdate
# properties.highway
# properties.route
# properties.bus
# properties.public_transport
# properties.shelter
# properties.cost:coffee
# properties.capacity
# properties.bicycle_parking
# properties.addr:suburb
# properties.odbl
# properties.service
# properties.bar
# properties.sport
# properties.diet:pescetarian
# properties.payment
# properties.access
# properties.postal_code
# properties.addr:unit
# properties.email
# properties.lit
# properties.dispensing
# properties.name:ko
# properties.opening_hours:note
# properties.internet_access:fee
# properties.surface
# properties.supervised
# properties.hookah
# properties.addr:housename
# properties.shop
# properties.oven
# properties.air_conditioning
# properties.contact:email
# properties.contact:facebook
# properties.contact:phone
# properties.contact:twitter
# properties.facebook
# properties.gay
# properties.lgbtq
# properties.wheelchair:note
# properties.outdoor
# properties.name:am
# properties.fax
# properties.reservation
# properties.tourism
# properties.housesuffix
# properties.alcohol
# properties.disused:amenity
# properties.contact:instagram
# properties.payment:cash
# properties.owner
# properties.payment:american_express
# properties.payment:discover_card
# properties.payment:mastercard
# properties.payment:visa
# properties.loc_name
# properties.addr:suite
# properties.wifi
# properties.future:amenity
# properties.leisure
# properties.historic:shop
# properties.construction:amenity
# properties.opening_date
# properties.seating
# properties.microbrewery
# properties.club
# properties.female
# properties.dcgis:facuse
# properties.screen
# properties.bottle
# properties.wetap:flow
# properties.wetap:photo
# properties.wetap:quality
# properties.wetap:status
# properties.wetap:temperature
# properties.fountain
# properties.emergency
# properties.colour
# properties.material
# properties.ref
# properties.rental
# properties.crypt
# properties.fuel:electricity
# properties.maxstay
# properties.drive_in
# properties.name:it
# properties.indoor
# properties.drinking_water:seasonal
# properties.wetap:statusnote
# properties.wetap:credit
# properties.bakery
# properties.alt_name:el
# properties.alt_name:es
# properties.alt_name:fr
# properties.alt_name:hi
# properties.alt_name:ko
# properties.alt_name:mn
# properties.alt_name:tl
# properties.alt_name:zh
# properties.alt_name:zh_pinyin
# properties.name:hi
# properties.name:ja
# properties.name:pt
# properties.name:ru
# properties.name:vi
# properties.name:zh
# properties.name:zh_pinyin
# properties.note:en
# properties.note:ko
# properties.dcgis:captureyear
# properties.height
# properties.recycling:cans
# properties.recycling:clothes
# properties.recycling:glass_bottles
# properties.recycling:paper
# properties.diesel
# properties.male
# properties.toilets
# properties.URL
# properties.craft
# properties.name:old
# properties.collection_times
# properties.brewery
# properties.old_name2
# properties.contact:fax
# properties.park_ride
# properties.service:bicycle:pump
# properties.service:bicycle:tools
# properties.door
# properties.entrance
# properties.car_wash
# properties.mapillary
# properties.construction
# properties.structure
# properties.service:bicycle:chain_tool
# properties.payment:contactless
# properties.payment:credit_cards
# properties.wheelchair:description
# properties.operator:wikidata
# properties.operator:wikipedia
# properties.socket:chademo
# properties.socket:type1
# properties.socket:tesla_roadster
# properties.addr:source
# properties.year
# properties.max_age
# properties.min_age
# properties.survey:date
# properties.drinking_water
# properties.cat
# properties.dog
# properties.indoor_seating
# properties.charge
# properties.seats
# properties.currency:USD
# properties.operator_1
# properties.operator_2
# properties.community_centre:for
# properties.recycling:plastic_bottles
# properties.genre
# properties.karaoke
# properties.bicycle
# properties.motorcar
# properties.motorcycle
# properties.start_date
# properties.addr:floor
# properties.proposed:amenity
# properties.public_bookcase:type
# properties.vending_1
# properties.vending_2
# properties.animal_boarding
# properties.organic
# properties.waste
# properties.image
# properties.dish
# properties.barrier
# properties.post_box:type
# properties.payment:electronic_purses
# properties.booth
# properties.OWNER
# properties.cocktails
# properties.happy_hours
# properties.ferry
# properties.car
# properties.addr:place
# properties.pump
# properties.tools
# properties.operator:type
# properties.after_school
# properties.isced:level
# properties.nursery
# properties.preschool
# properties.toilets:disposal
# properties.toilets:position
# properties.display
# longitude
# latitude

# %%
gds.df.count().sort_values(ascending=False).head(50)
# Out:
# latitude                       5627
# longitude                      5627
# id                             5627
# properties.@id                 5627
# properties.amenity             5627
# geometry.type                  5627
# geometry.coordinates           5627
# type                           5627
# properties.name                3942
# properties.addr:street         1525
# properties.addr:housenumber    1519
# properties.source              1311
# properties.cuisine             1066
# properties.ele                  800
# properties.addr:state           770
# properties.dataset              736
# properties.gnis:feature_id      712
# properties.addr:city            680
# properties.brand                665
# properties.brand:wikidata       647
# properties.brand:wikipedia      644
# properties.addr:postcode        585
# properties.website              529
# properties.gnis:county_id       514
# properties.gnis:created         514
# properties.gnis:state_id        514
# properties.takeaway             411
# properties.opening_hours        405
# properties.capacity             404
# properties.phone                375
# properties.operator             365
# properties.dcgis:dataset        294
# properties.dcgis:gis_id         294
# properties.network              294
# properties.dcgis:pubdate        294
# properties.wheelchair           273
# properties.religion             259
# properties.gnis:county_name     193
# properties.gnis:import_uuid     192
# properties.gnis:reviewed        191
# properties.ref                  166
# properties.denomination         158
# properties.dcgis:square         155
# properties.dcgis:lot            155
# properties.official_name        152
# properties.outdoor_seating      133
# properties.addr:country         127
# properties.gnis:edited          122
# properties.OWNER                 98
# properties.level                 95
# dtype: int64
